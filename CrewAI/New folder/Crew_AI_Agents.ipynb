# %%
import os
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool
import openai

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# 2025-02-20 00:15:08,011 - 25020 - main.py-main:28 - WARNING: Python-dotenv could not parse statement starting at line 10
# True

# %%
OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")
SERPER_API_KEY=os.getenv("SERPER_API_KEY")

# %%
search_tool = SerperDevTool()

# %%
researcher = Agent(
    role = "Senior Healthcare Research Analyst",
    goal = "Investigate and report on the latest advancements in AI applications for the healthcare industry in 2024.",
    backstory = """You work at a prominent healthcare research institute.
    Your expertise lies in sourcing and analyzing information on AI technologies used in healthcare. You excel at breaking down complex medical data and presenting it in an accessible and insightful manner.""",
    verbose = False,
    allow_delegation = False,
    tools = [search_tool],
    llm = openai(model_name="gpt-4o-mini", temperature=0.7)
)
writer = Agent(
    role = "Expert Healthcare Technology Writer",
    goal = "Craft concise and informative articles summarizing the latest advancements in AI applications within the healthcare sector in 2024.",
    backstory = """You are a well-respected content strategist with a knack for creating engaging and informative articles.
    Your expertise lies in transforming complex healthcare and AI concepts into clear, compelling narratives that are easily understood by a broad audience.""",
    verbose = True,
    allow_delegation = True,
    llm = openai(model_name="gpt-4o-mini", temperature=0.7)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 9
#       1 researcher = Agent(
#       2     role = "Senior Healthcare Research Analyst",
#       3     goal = "Investigate and report on the latest advancements in AI applications for the healthcare industry in 2024.",
#       4     backstory = """You work at a prominent healthcare research institute.
#       5     Your expertise lies in sourcing and analyzing information on AI technologies used in healthcare. You excel at breaking down complex medical data and presenting it in an accessible and insightful manner.""",
#       6     verbose = False,
#       7     allow_delegation = False,
#       8     tools = [search_tool],
# ----> 9     llm = openai(model_name="gpt-4o-mini", temperature=0.7)
#      10 )
#      11 writer = Agent(
#      12     role = "Expert Healthcare Technology Writer",
#      13     goal = "Craft concise and informative articles summarizing the latest advancements in AI applications within the healthcare sector in 2024.",
#    (...)
#      18     llm = openai(model_name="gpt-4o-mini", temperature=0.7)
#      19 )
#
# TypeError: 'module' object is not callable

# %%
task1 = Task(
    description = "Investigate the most recent breakthroughs in AI applications for healthcare.",
    expected_output = "A detailed summary of the latest innovations in AI technology within the healthcare sector.",
    agent = researcher
)

task2 = Task(
    description = "Compose a concise and informative article highlighting the latest innovations in AI applications for healthcare.",
    expected_output = "An engaging and well-structured article on the recent advancements in AI technology for healthcare.",
    agent = writer
)

# %%
crew = Crew(
    agents = [researcher, writer],
    tasks = [task1, task2],
    verbose = 1
)
# Out:
# 2025-02-19 23:58:50,840 - 25020 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed

# %%
final = crew.kickoff()
# Out:
# # Agent: Senior Healthcare Research Analyst
# ## Task: Investigate the most recent breakthroughs in AI applications for healthcare.
# 2025-02-19 23:59:03,529 - 25020 - llm.py-llm:348 - ERROR: LiteLLM call failed: litellm.RateLimitError: RateLimitError: OpenAIException - Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#  Error during LLM call: litellm.RateLimitError: RateLimitError: OpenAIException - Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\llms\openai\openai.py:711, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     710             else:
# --> 711                 raise e
#     712 except OpenAIError as e:
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\llms\openai\openai.py:638, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     626 logging_obj.pre_call(
#     627     input=messages,
#     628     api_key=openai_client.api_key,
#    (...)
#     634     },
#     635 )
#     637 headers, response = (
# --> 638     self.make_sync_openai_chat_completion_request(
#     639         openai_client=openai_client,
#     640         data=data,
#     641         timeout=timeout,
#     642         logging_obj=logging_obj,
#     643     )
#     644 )
#     646 logging_obj.model_call_details["response_headers"] = headers
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\litellm_core_utils\logging_utils.py:145, in track_llm_api_timing.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     144 try:
# --> 145     result = func(*args, **kwargs)
#     146     return result
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\llms\openai\openai.py:457, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     456 else:
# --> 457     raise e
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\llms\openai\openai.py:439, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     438 try:
# --> 439     raw_response = openai_client.chat.completions.with_raw_response.create(
#     440         **data, timeout=timeout
#     441     )
#     443     if hasattr(raw_response, "headers"):
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     878 validate_response_format(response_format)
# --> 879 return self._post(
#     880     "/chat/completions",
#     881     body=maybe_transform(
#     882         {
#     883             "messages": messages,
#     884             "model": model,
#     885             "audio": audio,
#     886             "frequency_penalty": frequency_penalty,
#     887             "function_call": function_call,
#     888             "functions": functions,
#     889             "logit_bias": logit_bias,
#     890             "logprobs": logprobs,
#     891             "max_completion_tokens": max_completion_tokens,
#     892             "max_tokens": max_tokens,
#     893             "metadata": metadata,
#     894             "modalities": modalities,
#     895             "n": n,
#     896             "parallel_tool_calls": parallel_tool_calls,
#     897             "prediction": prediction,
#     898             "presence_penalty": presence_penalty,
#     899             "reasoning_effort": reasoning_effort,
#     900             "response_format": response_format,
#     901             "seed": seed,
#     902             "service_tier": service_tier,
#     903             "stop": stop,
#     904             "store": store,
#     905             "stream": stream,
#     906             "stream_options": stream_options,
#     907             "temperature": temperature,
#     908             "tool_choice": tool_choice,
#     909             "tools": tools,
#     910             "top_logprobs": top_logprobs,
#     911             "top_p": top_p,
#     912             "user": user,
#     913         },
#     914         completion_create_params.CompletionCreateParams,
#     915     ),
#     916     options=make_request_options(
#     917         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918     ),
#     919     cast_to=ChatCompletion,
#     920     stream=stream or False,
#     921     stream_cls=Stream[ChatCompletionChunk],
#     922 )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1287 opts = FinalRequestOptions.construct(
#    1288     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289 )
# -> 1290 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055     err.response.close()
# -> 1056     return self._retry_request(
#    1057         input_options,
#    1058         cast_to,
#    1059         retries_taken=retries_taken,
#    1060         response_headers=err.response.headers,
#    1061         stream=stream,
#    1062         stream_cls=stream_cls,
#    1063     )
#    1065 # If the response is streamed then we need to explicitly read the response
#    1066 # to completion before attempting to access the response text.
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1103 time.sleep(timeout)
# -> 1105 return self._request(
#    1106     options=options,
#    1107     cast_to=cast_to,
#    1108     retries_taken=retries_taken + 1,
#    1109     stream=stream,
#    1110     stream_cls=stream_cls,
#    1111 )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055     err.response.close()
# -> 1056     return self._retry_request(
#    1057         input_options,
#    1058         cast_to,
#    1059         retries_taken=retries_taken,
#    1060         response_headers=err.response.headers,
#    1061         stream=stream,
#    1062         stream_cls=stream_cls,
#    1063     )
#    1065 # If the response is streamed then we need to explicitly read the response
#    1066 # to completion before attempting to access the response text.
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1103 time.sleep(timeout)
# -> 1105 return self._request(
#    1106     options=options,
#    1107     cast_to=cast_to,
#    1108     retries_taken=retries_taken + 1,
#    1109     stream=stream,
#    1110     stream_cls=stream_cls,
#    1111 )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\openai\_base_client.py:1071, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1070     log.debug("Re-raising status error")
# -> 1071     raise self._make_status_error_from_response(err.response) from None
#    1073 return self._process_response(
#    1074     cast_to=cast_to,
#    1075     options=options,
#    (...)
#    1079     retries_taken=retries_taken,
#    1080 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\main.py:1692, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1686     logging.post_call(
#    1687         input=messages,
#    1688         api_key=api_key,
#    1689         original_response=str(e),
#    1690         additional_args={"headers": headers},
#    1691     )
# -> 1692     raise e
#    1694 if optional_params.get("stream", False):
#    1695     ## LOGGING
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\main.py:1665, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1664 try:
# -> 1665     response = openai_chat_completions.completion(
#    1666         model=model,
#    1667         messages=messages,
#    1668         headers=headers,
#    1669         model_response=model_response,
#    1670         print_verbose=print_verbose,
#    1671         api_key=api_key,
#    1672         api_base=api_base,
#    1673         acompletion=acompletion,
#    1674         logging_obj=logging,
#    1675         optional_params=optional_params,
#    1676         litellm_params=litellm_params,
#    1677         logger_fn=logger_fn,
#    1678         timeout=timeout,  # type: ignore
#    1679         custom_prompt_dict=custom_prompt_dict,
#    1680         client=client,  # pass AsyncOpenAI, OpenAI client
#    1681         organization=organization,
#    1682         custom_llm_provider=custom_llm_provider,
#    1683     )
#    1684 except Exception as e:
#    1685     ## LOGGING - log the original exception returned
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\llms\openai\openai.py:721, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     720     error_headers = getattr(error_response, "headers", None)
# --> 721 raise OpenAIError(
#     722     status_code=status_code, message=error_text, headers=error_headers
#     723 )
#
# OpenAIError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# During handling of the above exception, another exception occurred:
#
# RateLimitError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 final = crew.kickoff()
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\crew.py:576, in Crew.kickoff(self, inputs)
#     573 metrics: List[UsageMetrics] = []
#     575 if self.process == Process.sequential:
# --> 576     result = self._run_sequential_process()
#     577 elif self.process == Process.hierarchical:
#     578     result = self._run_hierarchical_process()
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\crew.py:683, in Crew._run_sequential_process(self)
#     681 def _run_sequential_process(self) -> CrewOutput:
#     682     """Executes tasks sequentially and returns the final output."""
# --> 683     return self._execute_tasks(self.tasks)
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\crew.py:781, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     778     futures.clear()
#     780 context = self._get_context(task, task_outputs)
# --> 781 task_output = task.execute_sync(
#     782     agent=agent_to_use,
#     783     context=context,
#     784     tools=tools_for_task,
#     785 )
#     786 task_outputs.append(task_output)
#     787 self._process_task_result(task, task_output)
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\task.py:302, in Task.execute_sync(self, agent, context, tools)
#     295 def execute_sync(
#     296     self,
#     297     agent: Optional[BaseAgent] = None,
#     298     context: Optional[str] = None,
#     299     tools: Optional[List[BaseTool]] = None,
#     300 ) -> TaskOutput:
#     301     """Execute the task synchronously."""
# --> 302     return self._execute_core(agent, context, tools)
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\task.py:366, in Task._execute_core(self, agent, context, tools)
#     362 tools = tools or self.tools or []
#     364 self.processed_by_agents.add(agent.role)
# --> 366 result = agent.execute_task(
#     367     task=self,
#     368     context=context,
#     369     tools=tools,
#     370 )
#     372 pydantic_output, json_output = self._export_output(result)
#     373 task_output = TaskOutput(
#     374     name=self.name,
#     375     description=self.description,
#    (...)
#     381     output_format=self._get_output_format(),
#     382 )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agent.py:254, in Agent.execute_task(self, task, context, tools)
#     251 except Exception as e:
#     252     if e.__class__.__module__.startswith("litellm"):
#     253         # Do not retry on litellm errors
# --> 254         raise e
#     255     self._times_executed += 1
#     256     if self._times_executed > self.max_retry_limit:
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agent.py:243, in Agent.execute_task(self, task, context, tools)
#     240     task_prompt = self._use_trained_data(task_prompt=task_prompt)
#     242 try:
# --> 243     result = self.agent_executor.invoke(
#     244         {
#     245             "input": task_prompt,
#     246             "tool_names": self.agent_executor.tools_names,
#     247             "tools": self.agent_executor.tools_description,
#     248             "ask_for_human_input": task.human_input,
#     249         }
#     250     )["output"]
#     251 except Exception as e:
#     252     if e.__class__.__module__.startswith("litellm"):
#     253         # Do not retry on litellm errors
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:112, in CrewAgentExecutor.invoke(self, inputs)
#     109 except Exception as e:
#     110     if e.__class__.__module__.startswith("litellm"):
#     111         # Do not retry on litellm errors
# --> 112         raise e
#     113     else:
#     114         self._handle_unknown_error(e)
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:102, in CrewAgentExecutor.invoke(self, inputs)
#      99 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     101 try:
# --> 102     formatted_answer = self._invoke_loop()
#     103 except AssertionError:
#     104     self._printer.print(
#     105         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     106         color="red",
#     107     )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:160, in CrewAgentExecutor._invoke_loop(self)
#     157 except Exception as e:
#     158     if e.__class__.__module__.startswith("litellm"):
#     159         # Do not retry on litellm errors
# --> 160         raise e
#     161     if self._is_context_length_exceeded(e):
#     162         self._handle_context_length()
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:140, in CrewAgentExecutor._invoke_loop(self)
#     136     break
#     138 self._enforce_rpm_limit()
# --> 140 answer = self._get_llm_response()
#     141 formatted_answer = self._process_llm_response(answer)
#     143 if isinstance(formatted_answer, AgentAction):
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:210, in CrewAgentExecutor._get_llm_response(self)
#     205 except Exception as e:
#     206     self._printer.print(
#     207         content=f"Error during LLM call: {e}",
#     208         color="red",
#     209     )
# --> 210     raise e
#     212 if not answer:
#     213     self._printer.print(
#     214         content="Received None or empty response from LLM call.",
#     215         color="red",
#     216     )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:201, in CrewAgentExecutor._get_llm_response(self)
#     199 """Call the LLM and return the response, handling any invalid responses."""
#     200 try:
# --> 201     answer = self.llm.call(
#     202         self.messages,
#     203         callbacks=self.callbacks,
#     204     )
#     205 except Exception as e:
#     206     self._printer.print(
#     207         content=f"Error during LLM call: {e}",
#     208         color="red",
#     209     )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\crewai\llm.py:291, in LLM.call(self, messages, tools, callbacks, available_functions)
#     288 params = {k: v for k, v in params.items() if v is not None}
#     290 # --- 2) Make the completion call
# --> 291 response = litellm.completion(**params)
#     292 response_message = cast(Choices, cast(ModelResponse, response).choices)[
#     293     0
#     294 ].message
#     295 text_response = response_message.content or ""
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\utils.py:1154, in client.<locals>.wrapper(*args, **kwargs)
#    1150 if logging_obj:
#    1151     logging_obj.failure_handler(
#    1152         e, traceback_exception, start_time, end_time
#    1153     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1154 raise e
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\utils.py:1032, in client.<locals>.wrapper(*args, **kwargs)
#    1030         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1031 # MODEL CALL
# -> 1032 result = original_function(*args, **kwargs)
#    1033 end_time = datetime.datetime.now()
#    1034 if "stream" in kwargs and kwargs["stream"] is True:
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\main.py:3068, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3065     return response
#    3066 except Exception as e:
#    3067     ## Map to OpenAI Exception
# -> 3068     raise exception_type(
#    3069         model=model,
#    3070         custom_llm_provider=custom_llm_provider,
#    3071         original_exception=e,
#    3072         completion_kwargs=args,
#    3073         extra_kwargs=kwargs,
#    3074     )
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2201, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2199 if exception_mapping_worked:
#    2200     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2201     raise e
#    2202 else:
#    2203     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File f:\dev25\Building-Agentic-AI\CrewAI-app\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:425, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     423 elif original_exception.status_code == 429:
#     424     exception_mapping_worked = True
# --> 425     raise RateLimitError(
#     426         message=f"RateLimitError: {exception_provider} - {message}",
#     427         model=model,
#     428         llm_provider=custom_llm_provider,
#     429         response=getattr(original_exception, "response", None),
#     430         litellm_debug_info=extra_information,
#     431     )
#     432 elif original_exception.status_code == 503:
#     433     exception_mapping_worked = True
#
# RateLimitError: litellm.RateLimitError: RateLimitError: OpenAIException - Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
